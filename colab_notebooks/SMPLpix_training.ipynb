# %%
import os
from getpass import getpass
import urllib

def colab_clone_repo(repo_name, user):
  
  password = getpass('Password: ')
  password = urllib.parse.quote(password) # your password is converted into url format

  cmd_string = 'git clone https://{0}:{1}@github.com/{0}/{2}.git'.format(user, password, repo_name)

  os.system(cmd_string)
  cmd_string, password = "", "" # removing the password from the variable

  return

# %%
# %cd /content
# !rm -rf smplpix
colab_clone_repo('smplpix', 'sergeyprokudin')
# %cd /content/smplpix
# !python setup.py install
# Out:
# /content
# Password: ··········
# /content/smplpix
# running install
# running bdist_egg
# running egg_info
# creating smplpix.egg-info
# writing smplpix.egg-info/PKG-INFO
# writing dependency_links to smplpix.egg-info/dependency_links.txt
# writing requirements to smplpix.egg-info/requires.txt
# writing top-level names to smplpix.egg-info/top_level.txt
# writing manifest file 'smplpix.egg-info/SOURCES.txt'
# adding license file 'LICENSE' (matched pattern 'LICEN[CS]E*')
# writing manifest file 'smplpix.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/smplpix
# copying smplpix/dataset.py -> build/lib/smplpix
# copying smplpix/vgg.py -> build/lib/smplpix
# copying smplpix/train.py -> build/lib/smplpix
# copying smplpix/training.py -> build/lib/smplpix
# copying smplpix/unet.py -> build/lib/smplpix
# copying smplpix/__init__.py -> build/lib/smplpix
# copying smplpix/utils.py -> build/lib/smplpix
# copying smplpix/args.py -> build/lib/smplpix
# copying smplpix/eval.py -> build/lib/smplpix
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/dataset.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/vgg.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/train.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/training.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/unet.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/__init__.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/utils.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/args.py -> build/bdist.linux-x86_64/egg/smplpix
# copying build/lib/smplpix/eval.py -> build/bdist.linux-x86_64/egg/smplpix
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/dataset.py to dataset.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/vgg.py to vgg.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/train.py to train.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/training.py to training.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/unet.py to unet.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/utils.py to utils.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/args.py to args.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplpix/eval.py to eval.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplpix.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplpix.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplpix.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplpix.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplpix.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/smplpix-1.0-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing smplpix-1.0-py3.7.egg
# Copying smplpix-1.0-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding smplpix 1.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/smplpix-1.0-py3.7.egg
# Processing dependencies for smplpix==1.0
# Searching for pyrender
# Reading https://pypi.org/simple/pyrender/
# Downloading https://files.pythonhosted.org/packages/28/88/174c28b9d3d03cf6d8edb6f637458f30f1cf1a2bd7a617cbd9dadb1740f6/pyrender-0.1.45-py3-none-any.whl#sha256=5cf751d1f21fba4640e830cef3a0b5a95ed0f05677bf92c6b8330056b4023aeb
# Best match: pyrender 0.1.45
# Processing pyrender-0.1.45-py3-none-any.whl
# Installing pyrender-0.1.45-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding pyrender 0.1.45 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/pyrender-0.1.45-py3.7.egg
# Searching for trimesh
# Reading https://pypi.org/simple/trimesh/
# Downloading https://files.pythonhosted.org/packages/5d/1d/2bb87a294a7c090130f8648c645dee038739cd03efc0f6e73c5bba47af20/trimesh-3.9.15-py3-none-any.whl#sha256=663ebb267bfba06e3588e954e686caa954b42506531b0bd23c7de55402f24a8c
# Best match: trimesh 3.9.15
# Processing trimesh-3.9.15-py3-none-any.whl
# Installing trimesh-3.9.15-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding trimesh 3.9.15 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/trimesh-3.9.15-py3.7.egg
# Searching for freetype-py
# Reading https://pypi.org/simple/freetype-py/
# Downloading https://files.pythonhosted.org/packages/40/b5/56751e13f8b4a42f52c1b85ecce1446f83245190d820b42748eb8574ae43/freetype_py-2.2.0-py3-none-manylinux1_x86_64.whl#sha256=ede78730db61dc17c4524412aa3fccf038ede65400aa49b9e0a73a7e839a91a2
# Best match: freetype-py 2.2.0
# Processing freetype_py-2.2.0-py3-none-manylinux1_x86_64.whl
# Installing freetype_py-2.2.0-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding freetype-py 2.2.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/freetype_py-2.2.0-py3.7-linux-x86_64.egg
# Searching for PyOpenGL==3.1.0
# Reading https://pypi.org/simple/PyOpenGL/
# Downloading https://files.pythonhosted.org/packages/ce/33/ef0e3b40a3f4cbfcfb93511652673fb19d07bafac0611f01f6237d1978ed/PyOpenGL-3.1.0.zip#sha256=efa4e39a49b906ccbe66758812ca81ced13a6f26931ab2ba2dba2750c016c0d0
# Best match: PyOpenGL 3.1.0
# Processing PyOpenGL-3.1.0.zip
# Writing /tmp/easy_install-f2_f6nf1/PyOpenGL-3.1.0/setup.cfg
# Running PyOpenGL-3.1.0/setup.py -q bdist_egg --dist-dir /tmp/easy_install-f2_f6nf1/PyOpenGL-3.1.0/egg-dist-tmp-9rbg3393
# warning: no previously-included files matching '*.odt' found anywhere in distribution
# warning: no previously-included files matching '*.odp' found anywhere in distribution
# warning: no previously-included files matching '.cvsignore' found anywhere in distribution
# warning: no previously-included files matching '*.diff' found anywhere in distribution
# warning: no previously-included files found matching 'src/*.h'
# warning: no previously-included files found matching 'src/*.xml'
# warning: no previously-included files found matching 'src/*.zip'
# warning: no previously-included files found matching 'src/*.pdf'
# warning: no previously-included files found matching 'src/*.zip'
# warning: no previously-included files found matching 'src/*.txt'
# warning: no files found matching 'src/win32deps.py'
# warning: no files found matching 'src/toglinstall/get_togl.py'
# warning: no files found matching 'metadata.py'
# warning: no files found matching 'ChangeLog.txt'
# warning: no previously-included files found matching 'OpenGL_accelerate'
#   File "build/bdist.linux-x86_64/egg/OpenGL/GL/SGIX/async.py", line 58
#     from OpenGL.raw.GL.SGIX.async import *
#                                 ^
# SyntaxError: invalid syntax
#
# zip_safe flag not set; analyzing archive contents...
# OpenGL.Tk.__pycache__.__init__.cpython-37: module references __file__
# OpenGL.platform.__pycache__.ctypesloader.cpython-37: module references __file__
# creating /usr/local/lib/python3.7/dist-packages/PyOpenGL-3.1.0-py3.7.egg
# Extracting PyOpenGL-3.1.0-py3.7.egg to /usr/local/lib/python3.7/dist-packages
#   File "/usr/local/lib/python3.7/dist-packages/PyOpenGL-3.1.0-py3.7.egg/OpenGL/GL/SGIX/async.py", line 58
#     from OpenGL.raw.GL.SGIX.async import *
#                                 ^
# SyntaxError: invalid syntax
#
# Adding PyOpenGL 3.1.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/PyOpenGL-3.1.0-py3.7.egg
# Searching for torchvision==0.9.1+cu101
# Best match: torchvision 0.9.1+cu101
# Adding torchvision 0.9.1+cu101 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for torch==1.8.1+cu101
# Best match: torch 1.8.1+cu101
# Adding torch 1.8.1+cu101 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for scipy==1.4.1
# Best match: scipy 1.4.1
# Adding scipy 1.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pyglet==1.5.0
# Best match: pyglet 1.5.0
# Adding pyglet 1.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for networkx==2.5.1
# Best match: networkx 2.5.1
# Adding networkx 2.5.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for imageio==2.4.1
# Best match: imageio 2.4.1
# Adding imageio 2.4.1 to easy-install.pth file
# Installing imageio_download_bin script to /usr/local/bin
# Installing imageio_remove_bin script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Pillow==7.1.2
# Best match: Pillow 7.1.2
# Adding Pillow 7.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for setuptools==56.0.0
# Best match: setuptools 56.0.0
# Adding setuptools 56.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for typing-extensions==3.7.4.3
# Best match: typing-extensions 3.7.4.3
# Adding typing-extensions 3.7.4.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for future==0.16.0
# Best match: future 0.16.0
# Adding future 0.16.0 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for decorator==4.4.2
# Best match: decorator 4.4.2
# Adding decorator 4.4.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for smplpix==1.0

# %%
# !git pull origin
# Out:
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 15 (delta 11), reused 12 (delta 8), pack-reused 0
# Unpacking objects: 100% (15/15), done.
# From https://github.com/sergeyprokudin/smplpix
#    87aff00..ef3b3d5  main       -> origin/main
# Updating 87aff00..ef3b3d5
# Fast-forward
#  LICENSE          | 2 --
#  smplpix/eval.py  | 2 +-
#  smplpix/train.py | 6 +++---
#  3 files changed, 4 insertions(+), 6 deletions(-)

# %%
# !python /content/smplpix/smplpix/train.py --workdir='/content/smplpix_logs/' --data_url='https://www.dropbox.com/s/coapl05ahqalh09/smplpix_data_test_final.zip?dl=0'
# Out:
# ******************************************************************************************
# ****************************** SMPLpix Training Loop  ************************************
# ******************************************************************************************
#
# ARGUMENTS:
# Namespace(aug_prob=0.8, batch_size=4, data_dir=None, data_url='https://www.dropbox.com/s/coapl05ahqalh09/smplpix_data_test_final.zip?dl=0', device='cuda', downsample_factor=4, eval_every_nth_epoch=25, learning_rate=0.001, n_epochs=500, n_input_channels=3, n_output_channels=3, n_unet_blocks=5, resume=False, save_target=False, sched_patience=5, workdir='/content/smplpix_logs/')
# downloading zip from dropbox link: https://www.dropbox.com/s/coapl05ahqalh09/smplpix_data_test_final.zip?dl=0
# unzipping /content/smplpix_logs/data.zip
# defining the neural renderer model (U-Net)...
# starting training...
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:02<00:00, 240MB/s]
#   0% 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3458: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
#
# current epoch: 0
# mean VGG loss: 0.014888
# images saved at /content/smplpix_logs/logs/val_preds_0000
#   2% 8/500 [22:25<22:45:10, 166.48s/it]training interrupted, generating final animations...
# rendering SMPLpix predictions for /content/smplpix_logs/smplpix_data/train...
#
# 0it [00:00, ?it/s]
# 1it [00:00,  1.45it/s]
# 2it [00:01,  1.45it/s]
# 3it [00:02,  1.45it/s]
# 4it [00:02,  1.44it/s]
# 5it [00:03,  1.44it/s]
# 6it [00:04,  1.44it/s]
# 7it [00:04,  1.43it/s]
# 8it [00:05,  1.43it/s]
# 9it [00:06,  1.43it/s]
# 10it [00:06,  1.44it/s]
# 11it [00:07,  1.44it/s]
# 12it [00:08,  1.44it/s]
# 13it [00:09,  1.44it/s]
# 14it [00:09,  1.44it/s]
# 15it [00:10,  1.44it/s]
# 16it [00:11,  1.44it/s]
# 17it [00:11,  1.44it/s]
# 18it [00:12,  1.43it/s]
